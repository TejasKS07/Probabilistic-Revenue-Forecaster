# %%
import pandas as pd

# %%
df = pd.read_csv("bing_campaign_stats.csv")
df
# Out:
#       Unnamed: 0  CampaignId  TimePeriod  Revenue  Spend  Clicks  Impressions  \
# 0              0   566560838  2024-05-25     0.00   4.70      22          140
# 1              1   566560838  2024-05-26     0.00   4.30      14          120
# 2              2   566560838  2024-05-27     0.00   4.41      18          149
# 3              3   566560838  2024-05-28     0.00   2.61       8          135
# 4              4   566560838  2024-05-29     0.00   2.56      10          145
# ...          ...         ...         ...      ...    ...     ...          ...
# 2868        2868   570837633  2026-06-01     0.00   0.32       5          610
# 2869        2869   570837633  2026-06-02     0.00   0.46       9          495
# 2870        2870   570837633  2026-06-03     0.00   0.20       4          380
# 2871        2871   570837633  2026-06-04    48.99   1.28       5          216
# 2872        2872   570837633  2026-06-05     0.00   0.00       0            0
#
# ...
